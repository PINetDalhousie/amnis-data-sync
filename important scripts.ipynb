# %% [raw]
# # !tar czf myfiles.tar.gz *.py

# %%
#!pip3 install pandas
# !pip3 list
#!pip install seaborn
# Out:
# Package                           Version              Location
# --------------------------------- -------------------- ---------------------------------------------------
# absl-py                           0.9.0
# alembic                           1.4.2
# appdirs                           1.4.3
# apturl                            0.5.2
# argon2-cffi                       20.1.0
# astroid                           2.3.3
# astunparse                        1.6.3
# async-generator                   1.10
# atomicwrites                      1.1.5
# attrs                             19.3.0
# Automat                           0.8.0
# backcall                          0.2.0
# backports.entry-points-selectable 1.1.0
# bcrypt                            3.1.7
# bleach                            3.1.5
# blinker                           1.4
# Brlapi                            0.7.0
# cachetools                        4.1.1
# certifi                           2020.6.20
# certipy                           0.1.3
# cffi                              1.14.2
# chardet                           3.0.4
# chrome-gnome-shell                0.0.0
# Click                             7.0
# cloud-init                        20.4
# cloudpickle                       1.3.0
# colorama                          0.4.3
# command-not-found                 0.3
# configobj                         5.0.6
# constantly                        15.1.0
# cryptography                      2.8
# cupshelpers                       1.0
# cycler                            0.10.0
# dbus-python                       1.2.16
# decorator                         4.4.2
# defer                             1.0.6
# defusedxml                        0.6.0
# distlib                           0.3.2
# distro                            1.4.0
# distro-info                       0.23ubuntu1
# duplicity                         0.8.12.0
# entrypoints                       0.3
# fail2ban                          0.11.1
# fasteners                         0.14.1
# filelock                          3.0.12
# future                            0.18.2
# gast                              0.3.3
# google-auth                       1.20.0
# google-auth-oauthlib              0.4.1
# google-pasta                      0.2.0
# graphviz                          0.8.4
# grpcio                            1.30.0
# gym                               0.17.2
# h5py                              2.10.0
# httplib2                          0.14.0
# hyperlink                         19.0.0
# idna                              2.8
# importlib-metadata                1.5.0
# incremental                       16.10.1
# ipykernel                         5.3.4
# ipython                           7.17.0
# ipython-genutils                  0.2.0
# isort                             4.3.4
# jedi                              0.17.2
# Jinja2                            2.10.1
# joblib                            1.0.1
# json5                             0.9.5
# jsonpatch                         1.22
# jsonpointer                       2.0
# jsonschema                        3.2.0
# jupyter-client                    6.1.7
# jupyter-core                      4.6.3
# jupyter-server                    0.1.1
# jupyter-telemetry                 0.1.0
# jupyterhub                        1.1.0
# jupyterlab                        2.2.6
# jupyterlab-pygments               0.1.1
# jupyterlab-server                 1.2.0
# kafka-python                      2.0.2
# Keras                             2.4.3
# Keras-Preprocessing               1.1.2
# keyring                           18.0.1
# kiwisolver                        1.2.0
# language-selector                 0.1
# launchpadlib                      1.10.13
# lazr.restfulclient                0.14.2
# lazr.uri                          1.0.3
# lazy-object-proxy                 1.4.3
# lockfile                          0.12.2
# logilab-common                    1.4.3
# louis                             3.12.0
# macaroonbakery                    1.3.1
# Mako                              1.1.0
# Markdown                          3.2.2
# MarkupSafe                        1.1.0
# matplotlib                        3.3.1
# mccabe                            0.6.1
# meson                             0.53.2
# mininet                           2.3.0.dev6           /home/grad/ifath/.local/lib/python3.8/site-packages
# mistune                           0.8.4
# monotonic                         1.5
# more-itertools                    4.2.0
# mxnet                             1.6.0
# nbconvert                         5.6.1
# nbformat                          5.0.7
# netifaces                         0.10.4
# networkx                          2.5.1
# nnpy                              0.1
# nose                              1.3.7
# notebook                          6.1.3
# numpy                             1.18.5
# oauthlib                          3.1.0
# olefile                           0.46
# opt-einsum                        3.3.0
# ovs                               2.13.3
# packaging                         20.4
# pamela                            1.0.0
# pandas                            1.3.0
# pandocfilters                     1.4.2
# paramiko                          2.6.0
# parso                             0.7.1
# pexpect                           4.6.0
# pickleshare                       0.7.5
# Pillow                            7.2.0
# pip                               20.0.2
# platformdirs                      2.0.2
# pluggy                            0.13.0
# prometheus-client                 0.8.0
# prompt-toolkit                    3.0.6
# protobuf                          3.12.4
# psutil                            5.5.1
# ptyprocess                        0.6.0
# py                                1.8.1
# pyasn1                            0.4.2
# pyasn1-modules                    0.2.1
# pycairo                           1.16.2
# pycodestyle                       2.5.0
# pycparser                         2.20
# pycups                            1.9.73
# pyflakes                          2.1.1
# pyglet                            1.5.0
# Pygments                          2.6.1
# PyGObject                         3.36.0
# PyHamcrest                        1.9.0
# pyinotify                         0.9.6
# PyJWT                             1.7.1
# pylint                            2.4.4
# pymacaroons                       0.13.0
# PyNaCl                            1.3.0
# pyOpenSSL                         19.0.0
# pyparsing                         2.4.7
# pyRFC3339                         1.1
# pyrsistent                        0.15.5
# pyserial                          3.4
# pytest                            4.6.9
# python-apt                        2.0.0+ubuntu0.20.4.4
# python-dateutil                   2.7.3
# python-debian                     0.1.36ubuntu1
# python-editor                     1.0.4
# python-json-logger                0.1.11
# pytz                              2019.3
# pyxdg                             0.26
# PyYAML                            5.3.1
# pyzmq                             19.0.2
# reportlab                         3.5.34
# requests                          2.22.0
# requests-oauthlib                 1.3.0
# requests-unixsocket               0.2.0
# rsa                               4.6
# ruamel.yaml                       0.16.10
# ruamel.yaml.clib                  0.2.0
# scapy                             2.4.5
# scikit-learn                      0.24.2
# scipy                             1.4.1
# screen-resolution-extra           0.0.0
# seaborn                           0.11.2
# SecretStorage                     2.3.1
# Send2Trash                        1.5.0
# service-identity                  18.1.0
# setuptools                        45.2.0
# simplejson                        3.16.0
# six                               1.14.0
# sortedcontainers                  2.1.0
# sos                               4.0
# SQLAlchemy                        1.3.19
# ssh-import-id                     5.10
# sudospawner                       0.5.2
# systemd-python                    234
# tensorboard                       2.3.0
# tensorboard-plugin-wit            1.7.0
# tensorflow-estimator              2.3.0
# tensorflow-gpu                    2.3.0
# termcolor                         1.1.0
# terminado                         0.8.3
# testpath                          0.4.4
# threadpoolctl                     2.2.0
# thrift                            0.11.0
# torch                             1.6.0
# torchvision                       0.7.0
# tornado                           6.0.4
# traitlets                         4.3.3
# Twisted                           18.9.0
# ubuntu-advantage-tools            20.3
# ubuntu-drivers-common             0.0.0
# ufw                               0.36
# unattended-upgrades               0.1
# urllib3                           1.25.8
# usb-creator                       0.3.7
# virtualenv                        20.6.0
# voila                             0.1.22
# wadllib                           1.3.3
# wcwidth                           0.2.5
# webencodings                      0.5.1
# Werkzeug                          1.0.1
# wheel                             0.34.2
# wrapt                             1.12.1
# xkit                              0.0.0
# zipp                              1.0.0
# zope.interface                    4.7.1

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt
import pandas as pd
# Put dataset on my github repo 
df = pd.read_csv(r'D:\OneDrive - Dalhousie University\Documents\Monzurul Amin\boxplot_AMNIS.csv')
print(df)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-3214084a0f72> in <module>()
#       1 #import seaborn as sns
#       2 #import matplotlib.pyplot as plt
# ----> 3 import pandas as pd
#       4 # Put dataset on my github repo
#       5 df = pd.read_csv(r'D:\OneDrive - Dalhousie University\Documents\Monzurul Amin\boxplot_AMNIS.csv')
#
# ImportError: No module named pandas
